# %%
import numpy as np
import tensorflow as tf

from os import path
import matplotlib.pyplot as plt

from scipy.ndimage import gaussian_filter

from PIL import Image
import glob

# %%
np.random.seed(0)

# %%
sample_names = 'cil'
record_dir = path.join('..', '..', 'data', 'datasets', 'records', 'cil')
dataset_dir = path.join('..', '..', 'data', 'datasets', 'raw-images','cil')
files = glob.glob(path.join(dataset_dir, '*'))

obj_dims = (648, 486)

# fwhm in pixels, for convolution with Gaussian
fwhm_pixels = np.array([2, 2])

# %%
np.random.shuffle(files)

# %%
def normalize(im):
    """
    Normalizes im from 0 to 1.
    """
    im_max = np.max(im)
    im_min = np.min(im)
    return (im - im_min) / (im_max - im_min)

def _create_example(plane):
    """
    Creates and returns tf.Example from a given numpy array.
    """
    plane_feature = tf.train.Feature(float_list=tf.train.FloatList(value=plane.ravel()))
    feature = {
        'plane': plane_feature
    }
    return tf.train.Example(features=tf.train.Features(feature=feature))

# %%
np.seterr(invalid='raise')
# Out:
# {'divide': 'raise', 'invalid': 'warn', 'over': 'warn', 'under': 'ignore'}

# %%
np.seterr(divide='warn')
# Out:
# {'divide': 'raise', 'invalid': 'raise', 'over': 'warn', 'under': 'ignore'}

# %%
for i in range(len(files)):
    try:
        sample = Image.open(files[i])
        sample = sample.convert('L')
        sample = sample.resize(np.flip(obj_dims))

        sample = np.asarray(sample)

        fwhm_scaled = fwhm_pixels
        sigmas = fwhm_scaled / np.sqrt(8 * np.log(2))
        sample = gaussian_filter(sample, sigmas)
        sample = normalize(sample)

        sample.astype(np.float16)
        plt.imshow(sample)
        if np.sum(sample) > 300000:
            plt.title('{0}, {1}'.format(files[i], np.sum(sample)))
            plt.show()
    except Exception as e:
        print(files[i], e)
    
#     record_file = path.join(record_dir, sample_names + '-%.5d' % i + '.tfrecord')
#     with tf.io.TFRecordWriter(record_file) as writer:
#         tf_example = _create_example(sample)
#         writer.write(tf_example.SerializeToString())
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# ../../data/datasets/raw-images/cil/2834_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2672_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2712_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1970_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2727_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1936_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2146_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1910_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/8895_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2803_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1753_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1732_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2694_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1610_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1609_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1014_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1014_orig.tif'
# ../../data/datasets/raw-images/cil/2835_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1195_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1195_orig.tif'
# ../../data/datasets/raw-images/cil/1703_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2637_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1593_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/7825_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2854_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2161_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1695_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2661_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1793_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2306_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1182_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1182_orig.tif'
# ../../data/datasets/raw-images/cil/2155_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2692_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1272_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1272_orig.tif'
# ../../data/datasets/raw-images/cil/1161_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1161_orig.tif'
# ../../data/datasets/raw-images/cil/1063_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1063_orig.tif'
# ../../data/datasets/raw-images/cil/1667_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/35136_orig.tif invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2705_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1024_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1024_orig.tif'
# ../../data/datasets/raw-images/cil/7872_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2667_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2829_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1302_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1302_orig.tif'
# ../../data/datasets/raw-images/cil/7910_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2710_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1029_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1029_orig.tif'
# ../../data/datasets/raw-images/cil/2609_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1606_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1111_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1111_orig.tif'
# ../../data/datasets/raw-images/cil/2148_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2010_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1655_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2160_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2596_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1059_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1059_orig.tif'
# ../../data/datasets/raw-images/cil/841_orig.tif invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1915_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/8928_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2771_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2632_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/7834_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1785_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1300_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1300_orig.tif'
# ../../data/datasets/raw-images/cil/2786_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1191_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1191_orig.tif'
# ../../data/datasets/raw-images/cil/13684_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1050_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1050_orig.tif'
# ../../data/datasets/raw-images/cil/1154_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1154_orig.tif'
# ../../data/datasets/raw-images/cil/2228_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/35141_orig.tif invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2818_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2789_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1946_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1727_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2843_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2203_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2805_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2622_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1273_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1273_orig.tif'
# ../../data/datasets/raw-images/cil/7862_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/8847_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2575_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1717_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1153_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1153_orig.tif'
# ../../data/datasets/raw-images/cil/1789_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/7890_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2674_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1305_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1305_orig.tif'
# ../../data/datasets/raw-images/cil/1160_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1160_orig.tif'
# ../../data/datasets/raw-images/cil/8897_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2700_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1735_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/35133_orig.tif invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2641_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2804_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2272_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1164_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1164_orig.tif'
# ../../data/datasets/raw-images/cil/1112_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1112_orig.tif'
# ../../data/datasets/raw-images/cil/1997_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2217_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1181_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1181_orig.tif'
# ../../data/datasets/raw-images/cil/2741_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1635_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2312_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2713_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/155_orig.tif invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2687_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2753_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1588_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/9000_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1947_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2605_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/152_orig.tif invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1280_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1280_orig.tif'
# ../../data/datasets/raw-images/cil/1174_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1174_orig.tif'
# ../../data/datasets/raw-images/cil/7836_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1939_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/7887_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2844_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/7844_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1624_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1297_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1297_orig.tif'
# ../../data/datasets/raw-images/cil/2652_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/8888_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1662_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2054_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1744_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1794_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2204_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2182_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2606_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2723_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/8919_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/8840_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/7853_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/8956_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2855_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1919_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2196_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2150_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1189_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1189_orig.tif'
# ../../data/datasets/raw-images/cil/1193_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1193_orig.tif'
# ../../data/datasets/raw-images/cil/2246_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/9003_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/7818_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2614_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2593_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/7827_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1617_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2163_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1922_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1622_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2162_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2766_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1178_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1178_orig.tif'
# ../../data/datasets/raw-images/cil/2680_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1290_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1290_orig.tif'
# ../../data/datasets/raw-images/cil/1659_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1761_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2681_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2567_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1010_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1010_orig.tif'
# ../../data/datasets/raw-images/cil/1173_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1173_orig.tif'
# ../../data/datasets/raw-images/cil/2782_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1009_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1009_orig.tif'
# ../../data/datasets/raw-images/cil/2266_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1746_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2610_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1287_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1287_orig.tif'
# ../../data/datasets/raw-images/cil/1791_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/35138_orig.tif invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1991_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2548_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1288_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1288_orig.tif'
# ../../data/datasets/raw-images/cil/150_orig.tif invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1795_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2768_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2241_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2297_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2172_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2648_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2149_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/35130_orig.tif invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2564_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1156_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1156_orig.tif'
# ../../data/datasets/raw-images/cil/2315_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1742_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/32647_orig.jpg image file is truncated (8 bytes not processed)
# ../../data/datasets/raw-images/cil/1749_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2686_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/8933_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2578_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1023_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1023_orig.tif'
# ../../data/datasets/raw-images/cil/2218_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/7901_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1780_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1294_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1294_orig.tif'
# ../../data/datasets/raw-images/cil/7868_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2714_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1167_orig.tif cannot identify image file '../../data/datasets/raw-images/cil/1167_orig.tif'
# ../../data/datasets/raw-images/cil/8979_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/48826_orig.tif invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2558_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2191_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/1992_orig.tiff invalid value encountered in true_divide
# ../../data/datasets/raw-images/cil/2265_orig.tiff invalid value encountered in true_divide
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-355f034d4fe2> in <module>()
#       3         np.array([1]) / 0
#       4         sample = Image.open(files[i])
# ----> 5         sample = sample.convert('L')
#       6         sample = sample.resize(np.flip(obj_dims))
#       7
#
# /home/rshuai/.local/lib/python3.6/site-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#    1050
#    1051         try:
# -> 1052             im = self.im.convert(mode, dither)
#    1053         except ValueError:
#    1054             try:
#
# KeyboardInterrupt:

# %%
np.array([1])/0
# Out:
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# <ipython-input-13-f6baf8772c4a> in <module>()
# ----> 1 np.array([1])/0
#
# FloatingPointError: divide by zero encountered in true_divide
